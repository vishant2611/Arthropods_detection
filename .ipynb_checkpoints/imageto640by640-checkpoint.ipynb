# %%
from PIL import Image

# %%
def split_image(image_path, output_folder, tile_size=640, overlap=0):
    img = Image.open(image_path)
    width, height = img.size
    count=1
    to_save = image_path.split('\\')[1]
    
    print(f"Image dimensions: {width} x {height}")

    # Calculate the number of tiles in each dimension
    num_horizontal_tiles = (width - tile_size) // (tile_size - overlap) + 1
    num_vertical_tiles = (height - tile_size) // (tile_size - overlap) + 1

    print(f"Number of horizontal tiles: {num_horizontal_tiles}")
    print(f"Number of vertical tiles: {num_vertical_tiles}")

    for r in range(num_vertical_tiles):
        for c in range(num_horizontal_tiles):
            left = c * (tile_size - overlap)
            top = r * (tile_size - overlap)
            right = min(left + tile_size, width)
            bottom = min(top + tile_size, height)

            tile = img.crop((left, top, right, bottom))
            tile.save(f"{output_folder}/{to_save}_{count}.jpg")
            count=count+1

# %%
split_image("Vishant_New\PXL_20240202_190444747.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190457883.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190510813.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190531199.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190544738.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190636313.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190714871.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190746412.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190802742.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190819897.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190838048.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190910958.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190943720.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_190959416.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191015440.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191027416.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191040045.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191051401.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191126228.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191143438.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191155228.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191221312.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191238997.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Vishant_New\PXL_20240202_191257354.jpg", "Output_images", tile_size=640, overlap=100)
# Out:
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# ...

# %%
split_image("Tulaib_New\PXL_20240202_184225892.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184248219.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184304751.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184346429.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184403130.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184427885.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184531809.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184549751.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184605408.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184620129.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184649773.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184710894.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184937409.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184953025.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185037020.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185049130.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185113460.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185125752.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185211704.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185221262.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185234336.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185251354.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_185308400.jpg", "Output_images", tile_size=640, overlap=100)
split_image("Tulaib_New\PXL_20240202_184446137.jpg", "Output_images", tile_size=640, overlap=100)
# Out:
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# Number of horizontal tiles: 4
# Number of vertical tiles: 7
# Image dimensions: 2268 x 4032
# ...

# %%
split_image("Karishma_Old\IMG_9446.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9447.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9448.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9449.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9450.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9451.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9452.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9453.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9454.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9455.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9456.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9457.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9458.jpeg", "Output_images_old", tile_size=640, overlap=100)
split_image("Karishma_Old\IMG_9459.jpeg", "Output_images_old", tile_size=640, overlap=100)
